# %%
import pandas as pd
doc = pd.read_csv("C:/Users/이재영/OneDrive/바탕 화면/electric_train.csv/electirc_test.csv",encoding='utf-8-sig')

# %%
import numpy as np
import pandas as pd

# 시각화 라이브러리
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        
sns.set_style("whitegrid")

# %%
train_data = pd.read_csv("C:/Users/이재영/OneDrive/바탕 화면/electric_train.csv/electric_train.csv")
test_data = pd.read_csv("C:/Users/이재영/OneDrive/바탕 화면/electric_train.csv/electirc_test.csv")

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7593355 entries, 0 to 7593354
# Data columns (total 17 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   Unnamed: 0                  int64
#  1   electric_train.num          int64
#  2   electric_train.tm           object
#  3   electric_train.hh24         int64
#  4   electric_train.n            int64
#  5   electric_train.stn          int64
#  6   electric_train.sum_qctr     int64
#  7   electric_train.sum_load     float64
#  8   electric_train.n_mean_load  float64
#  9   electric_train.nph_ta       float64
#  10  electric_train.nph_hm       float64
#  11  electric_train.nph_ws_10m   float64
#  12  electric_train.nph_rn_60m   float64
#  13  electric_train.nph_ta_chi   float64
#  14  electric_train.weekday      int64
#  15  electric_train.week_name    int64
#  16  electric_train.elec         float64
# dtypes: float64(8), int64(8), object(1)
# memory usage: 984.9+ MB

# %%
train_data.describe()
# Out:
#          Unnamed: 0  electric_train.num  electric_train.hh24  \
# count  7.593355e+06        7.593355e+06         7.593355e+06
# mean   3.796678e+06        1.542260e+04         1.250000e+01
# std    2.192013e+06        3.312737e+03         6.922185e+00
# min    1.000000e+00        4.821000e+03         1.000000e+00
# 25%    1.898340e+06        1.246900e+04         7.000000e+00
# 50%    3.796678e+06        1.616000e+04         1.200000e+01
# 75%    5.695016e+06        1.839200e+04         1.800000e+01
# max    7.593355e+06        2.094700e+04         2.400000e+01
#
#        electric_train.n  electric_train.stn  electric_train.sum_qctr  \
# count      7.593355e+06        7.593355e+06             7.593355e+06
# mean       4.189762e+01        4.977980e+02             6.243189e+04
# std        4.242576e+01        2.564308e+02             5.673208e+04
# min        1.000000e+01        9.800000e+01             5.475000e+03
# ...

# %%
train_data.describe(include='O')
# Out:
#           electric_train.tm
# count               7593355
# unique                26304
# top     2020-07-02 01:00:00
# freq                    300

# %%
for col in train_data.columns:
    if train_data[col].dtype == 'object':
        categories = train_data[col].unique()
        print(f'[{col}] ({len(categories)})')
        print('\n'.join(categories))
        print()
# Out:
# [electric_train.tm] (26304)
# 2021-01-01 01:00:00
# 2021-01-01 02:00:00
# 2021-01-01 03:00:00
# 2021-01-01 04:00:00
# 2021-01-01 05:00:00
# 2021-01-01 06:00:00
# 2021-01-01 07:00:00
# 2021-01-01 08:00:00
# 2021-01-01 09:00:00
# 2021-01-01 10:00:00
# 2021-01-01 11:00:00
# 2021-01-01 12:00:00
# 2021-01-01 13:00:00
# 2021-01-01 14:00:00
# 2021-01-01 15:00:00
# 2021-01-01 16:00:00
# 2021-01-01 17:00:00
# 2021-01-01 18:00:00
# 2021-01-01 19:00:00
# 2021-01-01 20:00:00
# 2021-01-01 21:00:00
# 2021-01-01 22:00:00
# 2021-01-01 23:00:00
# 2021-01-02 00:00:00
# 2021-01-02 01:00:00
# 2021-01-02 02:00:00
# 2021-01-02 03:00:00
# 2021-01-02 04:00:00
# 2021-01-02 05:00:00
# 2021-01-02 06:00:00
# 2021-01-02 07:00:00
# 2021-01-02 08:00:00
# 2021-01-02 09:00:00
# 2021-01-02 10:00:00
# 2021-01-02 11:00:00
# 2021-01-02 12:00:00
# 2021-01-02 13:00:00
# 2021-01-02 14:00:00
# 2021-01-02 15:00:00
# 2021-01-02 16:00:00
# 2021-01-02 17:00:00
# 2021-01-02 18:00:00
# 2021-01-02 19:00:00
# 2021-01-02 20:00:00
# ...

# %%
train_data[''].value_counts()

# %%
doc.describe()
# Out:
#          Unnamed: 0  electric_test.num  electric_test.hh24  electric_test.stn  \
# count  2.838239e+06       2.838239e+06        2.838239e+06       2.838239e+06
# mean   1.419120e+06       1.525104e+04        1.250000e+01       4.830708e+02
# std    8.193292e+05       3.449973e+03        6.922188e+00       2.600145e+02
# min    1.000000e+00       2.385000e+03        1.000000e+00       9.800000e+01
# 25%    7.095605e+05       1.232200e+04        6.500000e+00       2.590000e+02
# 50%    1.419120e+06       1.586200e+04        1.200000e+01       4.430000e+02
# 75%    2.128680e+06       1.838650e+04        1.850000e+01       6.490000e+02
# max    2.838239e+06       2.094700e+04        2.400000e+01       9.910000e+02
#
#        electric_test.nph_ta  electric_test.nph_hm  electric_test.nph_ws_10m  \
# count          2.838239e+06          2.838239e+06              2.838239e+06
# mean           1.465222e+01          7.163156e+01              1.840850e+00
# ...

# %%
doc.corr(numeric_only=True)
# Out:
#                           Unnamed: 0  electric_test.num  electric_test.hh24  \
# Unnamed: 0                  1.000000      -3.382115e-01        8.241229e-06
# electric_test.num          -0.338212       1.000000e+00        2.548749e-07
# electric_test.hh24          0.000008       2.548749e-07        1.000000e+00
# electric_test.stn           0.213014      -2.295161e-01       -3.663887e-07
# electric_test.nph_ta        0.087516      -6.110002e-02        8.260207e-02
# electric_test.nph_hm        0.035932      -1.398006e-01       -1.307100e-01
# electric_test.nph_ws_10m    0.115148      -2.173111e-01        4.241045e-02
# electric_test.nph_rn_60m   -0.005511       2.383603e-02       -1.369916e-02
# electric_test.nph_ta_chi    0.035000      -6.801250e-02        9.254209e-02
# electric_test.weekday       0.000037      -1.971734e-07       -5.678640e-04
# electric_test.week_name     0.000024      -2.490834e-07       -4.188539e-04
#
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(2838239, 12))
sns.heatmap(data = doc.corr(), annot=True, fmt = '.2f', linewidths=0.5, cmap='Blues')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 5
#       3 import seaborn as sns
#       4 plt.figure(figsize=(2838239, 12))
# ----> 5 sns.heatmap(data = doc.corr(), annot=True, fmt = '.2f', linewidths=0.5, cmap='Blues')
#
# File c:\Users\이재영\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:11036, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11034 cols = data.columns
#   11035 idx = cols.copy()
# > 11036 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11038 if method == "pearson":
#   11039     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\이재영\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:1981, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1979 if dtype is not None:
#    1980     dtype = np.dtype(dtype)
# ...
